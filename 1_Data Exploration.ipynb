# %% [markdown]
# ## DATA EXPLORATION

# %% [markdown]
# *   Load the dataset that will used through the capstone project.
# *   Explore the dataset.
# *   Get familier with the data types.

# %% [markdown]
# <hr>

# %% [markdown]
# Import important Libraries.

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# Create file path and read files also create a DataFrame.

# %%
path = "C:\\Users\\Akshay\\Documents\\Data Analyst\\Developer project 1\\survey_results_public.csv"
df = pd.read_csv(path)
df.head()
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# ...

# %% [markdown]
# Find the *Shape* of data like number of rows and columns.

# %%
df.shape
# Out:
# (83439, 48)

# %% [markdown]
# Let's view the list of columns in the data frame.

# %%
df.columns
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %% [markdown]
# <hr>

# %% [markdown]
# It appears that shortcodes for questions have been used as column names. We can refer to the schema file to see the full text of each question.

# %%
schema = "C:\\Users\\Akshay\\Documents\\Data Analyst\\Developer project 1\\survey_results_schema.csv"
schema_df = pd.read_csv(schema)
schema_df.head()
# Out:
#         qname                                           question  force_resp  \
# 0          S0  <div><span style="font-size:19px;"><strong>Hel...       False
# 1    MetaInfo                                  Browser Meta Info       False
# 2          S1  <span style="font-size:22px; font-family: aria...       False
# 3  MainBranch  Which of the following options best describes ...        True
# 4  Employment  Which of the following best describes your cur...       False
#
#    type selector
# 0    DB       TB
# 1  Meta  Browser
# 2    DB       TB
# 3    MC     SAVR
# 4    MC     MAVR

# %%
schema_df = schema_df.set_index("qname")
schema_df
# Out:
#                                                              question  \
# qname
# S0                  <div><span style="font-size:19px;"><strong>Hel...
# MetaInfo                                            Browser Meta Info
# S1                  <span style="font-size:22px; font-family: aria...
# MainBranch          Which of the following options best describes ...
# Employment          Which of the following best describes your cur...
# Country             Where do you live? <span style="font-weight: b...
# US_State            <p>In which state or territory of the USA do y...
# UK_Country          In which part of the United Kingdom do you liv...
# S2                  <span style="font-size:22px; font-family: aria...
# EdLevel             Which of the following best describes the high...
# Age1stCode          At what age did you write your first line of c...
# LearnCode           How did you learn to code? Select all that apply.
# ...

# %%
schema_df= schema_df.drop(["S0","S1","S2","S3","S4","S5","S6","MetaInfo"],axis=0)
schema_df.head()
# Out:
#                                                      question  force_resp  \
# qname
# MainBranch  Which of the following options best describes ...        True
# Employment  Which of the following best describes your cur...       False
# Country     Where do you live? <span style="font-weight: b...        True
# US_State    <p>In which state or territory of the USA do y...       False
# UK_Country  In which part of the United Kingdom do you liv...       False
#
#            type selector
# qname
# MainBranch   MC     SAVR
# Employment   MC     MAVR
# Country      MC       DL
# US_State     MC       DL
# UK_Country   MC       DL

# %%
schema_raw = schema_df.question

# %%
schema_raw
# Out:
# qname
# MainBranch            Which of the following options best describes ...
# Employment            Which of the following best describes your cur...
# Country               Where do you live? <span style="font-weight: b...
# US_State              <p>In which state or territory of the USA do y...
# UK_Country            In which part of the United Kingdom do you liv...
# EdLevel               Which of the following best describes the high...
# Age1stCode            At what age did you write your first line of c...
# LearnCode             How did you learn to code? Select all that apply.
# YearsCode             Including any education, how many years have y...
# YearsCodePro          NOT including education, how many years have y...
# DevType               Which of the following describes your current ...
# OrgSize               Approximately how many people are employed by ...
# Currency              Which currency do you use day-to-day? If your ...
# ...

# %% [markdown]
# We can now use schema_raw to retrieve the full question text for any column in df.

# %%
schema_raw['Employment']
# Out:
# 'Which of the following best describes your current <b>employment status</b>?'

# %%
schema_raw['ToolsTech']
# Out:
# 'Which <strong>tools</strong> have you done extensive development work in over the past year, and which do you want to work in over the next year? (If you both worked with the technology and want to continue to do so, please check both boxes in that row.)'

# %% [markdown]
# <hr>

# %% [markdown]
# Now we will move to our dataset  **df** to explore more about it.

# %%
df.head(10)
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
# 5           6             I am a student who is learning to code
# 6           7                        I code primarily as a hobby
# 7           8             I am a student who is learning to code
# 8           9                     I am a developer by profession
# 9          10                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# ...

# %% [markdown]
# Get Familier with Data types.

# %%
df.dtypes
# Out:
# ResponseId                        int64
# MainBranch                       object
# Employment                       object
# Country                          object
# US_State                         object
# UK_Country                       object
# EdLevel                          object
# Age1stCode                       object
# LearnCode                        object
# YearsCode                        object
# YearsCodePro                     object
# DevType                          object
# OrgSize                          object
# Currency                         object
# CompTotal                       float64
# CompFreq                         object
# LanguageHaveWorkedWith           object
# LanguageWantToWorkWith           object
# DatabaseHaveWorkedWith           object
# DatabaseWantToWorkWith           object
# PlatformHaveWorkedWith           object
# PlatformWantToWorkWith           object
# WebframeHaveWorkedWith           object
# ...

# %%
schema_raw.to_csv("C:\\Users\\Akshay\\Documents\\Data Analyst\\Developer project 1\\schema_questions.csv")

# %% [markdown]
# **Thank you**.
# In next notebook we will work on Data processing and Data cleaning for same dataset
